# %% [markdown]
# # TRANSFORMÉ DE FOURIER AUDIO

# %%
from scipy.io import wavfile
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft, ifft
from scipy import fftpack
from scipy import signal
import IPython

# %%
samplerate, data = wavfile.read('cov1.wav')

# %%
print(samplerate)
# Out:
# 44100

# %%
print(data)

print(data.size)
# Out:
# [0 0 0 ... 0 0 0]
# 163840

# %%
plt.plot(data)

# %%
# création des variables Fourier et Fréquences, qui permettent de construire le spectre du signal.
fourier = fftpack.fft(data)
power = np.abs(fourier) # la variable power est créée pour éiminer les amplitudes négatives
frequences = fftpack.fftfreq(data.size)
plt.plot(np.abs(frequences), power)

fourier_save = fourier

# %%
# filtre du spectre avec du boolean indexing de Numpy
med = np.median(power)

fourier[ power < np.percentile(power,90) ] = 0

# Visualisation du spetre propre
plt.plot(np.abs(frequences), np.abs(fourier))

# %%
# Transformation de Fourier Inverse: genere un nouveau signal temporel depuis le spectre filtré
filtered_signal = fftpack.ifft(fourier)

# %%
plt.plot(filtered_signal)
# Out:
# /Users/baudouin/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
# Visualisation des résultats
plt.plot(np.abs(frequences), data, label='originel')
plt.plot(np.abs(frequences), filtered_signal, label='detrend')
plt.legend()
plt.show()
# Out:
# /Users/baudouin/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
wavfile.write("example.wav", samplerate, filtered_signal.astype(np.int16))
# Out:
# /Users/baudouin/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: ComplexWarning: Casting complex values to real discards the imaginary part
#   """Entry point for launching an IPython kernel.

# %%
type(filtered_signal[0])
# Out:
# numpy.complex128

# %%
f, t, Sxx = signal.spectrogram(np.abs(data),np.abs(data.size),return_onesided = True)
plt.pcolormesh(t, np.fft.fftshift(f), np.fft.fftshift(Sxx, axes = 0), shading='gouraud')
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()

# %%
def get_short_time_fourier_transform(soundwave):
    return librosa.stft(soundwave, n_fft=256)

def short_time_fourier_transform_amplitude_to_db(stft):
    return librosa.amplitude_to_db(stft)

def soundwave_to_np_spectogram(soundwave):
    step1 = get_short_time_fourier_transform(soundwave)
    step2 = short_time_fourier_transform_amplitude_to_db(step1)
    step3 = step2/100
    return step3

def inspect_data(sound):
    plt.figure()
    plt.plot(sound)
    IPython.display.display(IPython.display.Audio(sound, rate=samplerate))
    a = get_short_time_fourier_transform(sound)
    Xdb = short_time_fourier_transform_amplitude_to_db(a)
    plt.figure()
    plt.imshow(Xdb)
    plt.show()
    print("Length per sample: %d, shape of spectogram: %s, max: %f min: %f" % (len(sound), str(Xdb.shape), Xdb.max(), Xdb.min()))

inspect_data(filtered_signal)
# Out:
# /Users/baudouin/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /Users/baudouin/opt/anaconda3/lib/python3.7/site-packages/IPython/lib/display.py:157: ComplexWarning: Casting complex values to real discards the imaginary part
#   data = np.array(data, dtype=float)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-218-05ea4308bae7> in <module>
#      22     print("Length per sample: %d, shape of spectogram: %s, max: %f min: %f" % (len(sound), str(Xdb.shape), Xdb.max(), Xdb.min()))
#      23
# ...
